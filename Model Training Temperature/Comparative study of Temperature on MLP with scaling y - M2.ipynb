# %%
import numpy as np
import pandas as pd

# %%
abc_df = pd.read_csv('ABC_Feature_Matrix_Random.csv')
jwst_df = pd.read_csv('Interpolated_WASP-39b.csv')

# %%
x_spec = abc_df.iloc[:, 1:53]
y = abc_df.iloc[:, 53]

# %%
x_jwst = jwst_df.iloc[:,1:]

# %%
#Train Test Split
from sklearn.model_selection import train_test_split
x_spec_train, x_spec_test, y_train, y_test = train_test_split(x_spec, y, test_size = 0.2, random_state = 42)

# %%
X_train = x_spec_train.to_numpy()
X_test = x_spec_test.to_numpy()
X_jwst = x_jwst.to_numpy()

# %%
#Manual Normalisation - numpy
means_tr = X_train.mean(axis=1, keepdims=True)
stds_tr = X_train.std(axis=1, keepdims=True)
x_train_norm = (X_train - means_tr) / stds_tr

means_t = X_test.mean(axis=1, keepdims=True)
stds_t = X_test.std(axis=1, keepdims=True)
x_test_norm = (X_test - means_t) / stds_t

means = X_jwst.mean(axis=1, keepdims=True)
stds = X_jwst.std(axis=1, keepdims=True)
x_jwst_norm = (X_jwst - means) / stds

# %%
#Manual Normalization with mean and std

x_train_norm_ms= np.hstack([x_train_norm,means_tr,stds_tr])
x_test_norm_ms = np.hstack([x_test_norm,means_t,stds_t])
x_jwst_norm_ms = np.hstack([x_jwst_norm,means,stds])

# %%
y_train = np.log1p(y_train)
y_test   = np.log1p(y_test)

# %%
import optuna
import numpy as np
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor

# Validation split
X_tr, X_val, y_tr, y_val = train_test_split(
    x_train_norm_ms, y_train, test_size=0.20, random_state=42
)

def objective(trial):

    # Depth: restrict to 1–2 layers (3+ is too slow)
    n_layers = trial.suggest_int("n_layers", 1, 2)

    # Width: 64–192 units per layer (good speed/accuracy balance)
    hidden_layer_sizes = tuple([
        trial.suggest_int(f"units_l{i}", 64, 192, step=64)
        for i in range(n_layers)
    ])

    params = {
        "hidden_layer_sizes": hidden_layer_sizes,
        "activation": trial.suggest_categorical("activation", ["relu", "tanh"]),
        "solver": "adam",        # fastest for 20k × 55 data
        "alpha": trial.suggest_float("alpha", 1e-6, 1e-2, log=True),
        "learning_rate": trial.suggest_categorical("learning_rate", ["constant", "adaptive"]),
        "learning_rate_init": trial.suggest_float("learning_rate_init", 1e-4, 1e-2, log=True),
        "batch_size": trial.suggest_categorical("batch_size", [64, 128, 256]),
        "max_iter": 300,
        "early_stopping": True,
        "validation_fraction": 0.15,
        "random_state": 42,
    }

    model = MLPRegressor(**params)
    model.fit(X_tr, y_tr)

    preds = model.predict(X_val)
    r2 = r2_score(y_val, preds)

    trial.report(r2, step=0)
    if trial.should_prune():
        raise optuna.exceptions.TrialPruned()

    return r2


study = optuna.create_study(
    direction="maximize",
    sampler=optuna.samplers.TPESampler(),
    pruner=optuna.pruners.MedianPruner()
)

study.optimize(objective, n_trials=40, show_progress_bar=True)

print("Best R2:", study.best_value)
print("Best Params:", study.best_params)
# Out:
# [I 2025-11-26 00:43:32,852] A new study created in memory with name: no-name-20990d8d-0278-43fc-9750-ef027cb88e08
#   0%|          | 0/40 [00:00<?, ?it/s]
# [I 2025-11-26 00:43:58,034] Trial 0 finished with value: 0.9820792215968814 and parameters: {'n_layers': 1, 'units_l0': 128, 'activation': 'relu', 'alpha': 0.00011286572591663989, 'learning_rate': 'constant', 'learning_rate_init': 0.00022969208469251825, 'batch_size': 128}. Best is trial 0 with value: 0.9820792215968814.
# [I 2025-11-26 00:44:05,259] Trial 1 finished with value: 0.9773075004778798 and parameters: {'n_layers': 1, 'units_l0': 128, 'activation': 'relu', 'alpha': 2.2315875886236586e-05, 'learning_rate': 'constant', 'learning_rate_init': 0.00496246107078137, 'batch_size': 256}. Best is trial 0 with value: 0.9820792215968814.
# [I 2025-11-26 00:44:21,951] Trial 2 finished with value: 0.9958617798938049 and parameters: {'n_layers': 1, 'units_l0': 128, 'activation': 'tanh', 'alpha': 1.311117342234692e-06, 'learning_rate': 'adaptive', 'learning_rate_init': 0.009675472188620167, 'batch_size': 256}. Best is trial 2 with value: 0.9958617798938049.
# [I 2025-11-26 00:46:37,719] Trial 3 finished with value: 0.9947378184765199 and parameters: {'n_layers': 2, 'units_l0': 192, 'units_l1': 192, 'activation': 'tanh', 'alpha': 1.0893120174734092e-05, 'learning_rate': 'adaptive', 'learning_rate_init': 0.00014634403412149878, 'batch_size': 64}. Best is trial 2 with value: 0.9958617798938049.
# [I 2025-11-26 00:46:59,091] Trial 4 finished with value: 0.9967731215502307 and parameters: {'n_layers': 2, 'units_l0': 64, 'units_l1': 128, 'activation': 'tanh', 'alpha': 0.0003474818124797044, 'learning_rate': 'constant', 'learning_rate_init': 0.0021145337572501467, 'batch_size': 64}. Best is trial 4 with value: 0.9967731215502307.
# [I 2025-11-26 00:47:36,296] Trial 5 pruned.
# [I 2025-11-26 00:48:08,496] Trial 6 pruned.
# [I 2025-11-26 00:48:11,907] Trial 7 pruned.
# [I 2025-11-26 00:48:29,085] Trial 8 finished with value: 0.9949304873332258 and parameters: {'n_layers': 1, 'units_l0': 64, 'activation': 'tanh', 'alpha': 0.0006264061547385994, 'learning_rate': 'adaptive', 'learning_rate_init': 0.0005810866901461598, 'batch_size': 128}. Best is trial 4 with value: 0.9967731215502307.
# [I 2025-11-26 00:48:46,730] Trial 9 finished with value: 0.9962268299074961 and parameters: {'n_layers': 1, 'units_l0': 64, 'activation': 'tanh', 'alpha': 1.2327075705251313e-05, 'learning_rate': 'constant', 'learning_rate_init': 0.0008390778905811195, 'batch_size': 128}. Best is trial 4 with value: 0.9967731215502307.
# [I 2025-11-26 00:49:03,501] Trial 10 pruned.
# [I 2025-11-26 00:49:20,968] Trial 11 finished with value: 0.9968045392856245 and parameters: {'n_layers': 2, 'units_l0': 64, 'units_l1': 64, 'activation': 'tanh', 'alpha': 0.0003673899681426275, 'learning_rate': 'constant', 'learning_rate_init': 0.0014431920186286343, 'batch_size': 64}. Best is trial 11 with value: 0.9968045392856245.
# [I 2025-11-26 00:49:39,028] Trial 12 finished with value: 0.9967703986287383 and parameters: {'n_layers': 2, 'units_l0': 64, 'units_l1': 64, 'activation': 'tanh', 'alpha': 0.0007935596565409615, 'learning_rate': 'constant', 'learning_rate_init': 0.0016718958921322258, 'batch_size': 64}. Best is trial 11 with value: 0.9968045392856245.
# [I 2025-11-26 00:50:13,395] Trial 13 finished with value: 0.9965552902566526 and parameters: {'n_layers': 2, 'units_l0': 64, 'units_l1': 128, 'activation': 'tanh', 'alpha': 0.000491027371584115, 'learning_rate': 'constant', 'learning_rate_init': 0.0021067332733823996, 'batch_size': 64}. Best is trial 11 with value: 0.9968045392856245.
# [I 2025-11-26 00:50:44,813] Trial 14 pruned.
# [I 2025-11-26 00:51:05,686] Trial 15 finished with value: 0.9969829939511563 and parameters: {'n_layers': 2, 'units_l0': 64, 'units_l1': 64, 'activation': 'tanh', 'alpha': 0.00012789108960937205, 'learning_rate': 'constant', 'learning_rate_init': 0.0013136736099389392, 'batch_size': 64}. Best is trial 15 with value: 0.9969829939511563.
# [I 2025-11-26 00:51:35,240] Trial 16 finished with value: 0.9974999168813405 and parameters: {'n_layers': 2, 'units_l0': 64, 'units_l1': 64, 'activation': 'tanh', 'alpha': 8.315878750689293e-05, 'learning_rate': 'constant', 'learning_rate_init': 0.0011142929121074163, 'batch_size': 64}. Best is trial 16 with value: 0.9974999168813405.
# [I 2025-11-26 00:52:51,674] Trial 17 finished with value: 0.9971483647599269 and parameters: {'n_layers': 2, 'units_l0': 192, 'units_l1': 64, 'activation': 'tanh', 'alpha': 6.558488524785812e-05, 'learning_rate': 'constant', 'learning_rate_init': 0.0009701687635942501, 'batch_size': 64}. Best is trial 16 with value: 0.9974999168813405.
# [I 2025-11-26 00:53:31,809] Trial 18 pruned.
# [I 2025-11-26 00:54:58,546] Trial 19 finished with value: 0.9971827110740804 and parameters: {'n_layers': 2, 'units_l0': 192, 'units_l1': 64, 'activation': 'tanh', 'alpha': 6.278977623025775e-05, 'learning_rate': 'constant', 'learning_rate_init': 0.000766904766433508, 'batch_size': 64}. Best is trial 16 with value: 0.9974999168813405.
# [I 2025-11-26 00:56:52,459] Trial 20 pruned.
# [I 2025-11-26 00:57:52,754] Trial 21 finished with value: 0.997246834823681 and parameters: {'n_layers': 2, 'units_l0': 192, 'units_l1': 64, 'activation': 'tanh', 'alpha': 5.3018149158504415e-05, 'learning_rate': 'constant', 'learning_rate_init': 0.0008686016754481604, 'batch_size': 64}. Best is trial 16 with value: 0.9974999168813405.
# [I 2025-11-26 00:58:30,408] Trial 22 pruned.
# [I 2025-11-26 00:59:30,402] Trial 23 finished with value: 0.9977283855322285 and parameters: {'n_layers': 2, 'units_l0': 192, 'units_l1': 64, 'activation': 'tanh', 'alpha': 4.462091915918026e-05, 'learning_rate': 'constant', 'learning_rate_init': 0.0003181234015363141, 'batch_size': 64}. Best is trial 23 with value: 0.9977283855322285.
# [I 2025-11-26 01:00:29,577] Trial 24 finished with value: 0.9977296631954002 and parameters: {'n_layers': 2, 'units_l0': 192, 'units_l1': 64, 'activation': 'tanh', 'alpha': 3.0596375191410346e-05, 'learning_rate': 'constant', 'learning_rate_init': 0.00029480911418408156, 'batch_size': 64}. Best is trial 24 with value: 0.9977296631954002.
# [I 2025-11-26 01:01:24,137] Trial 25 pruned.
# [I 2025-11-26 01:01:44,682] Trial 26 pruned.
# [I 2025-11-26 01:03:12,033] Trial 27 finished with value: 0.9971593976158621 and parameters: {'n_layers': 2, 'units_l0': 192, 'units_l1': 128, 'activation': 'tanh', 'alpha': 3.6615756434273947e-06, 'learning_rate': 'constant', 'learning_rate_init': 0.0002863039535578614, 'batch_size': 64}. Best is trial 24 with value: 0.9977296631954002.
# [I 2025-11-26 01:05:11,404] Trial 28 finished with value: 0.9970102340166739 and parameters: {'n_layers': 2, 'units_l0': 192, 'units_l1': 64, 'activation': 'tanh', 'alpha': 0.0012814340451405407, 'learning_rate': 'constant', 'learning_rate_init': 0.00021680071593548636, 'batch_size': 256}. Best is trial 24 with value: 0.9977296631954002.
# [I 2025-11-26 01:05:34,319] Trial 29 pruned.
# [I 2025-11-26 01:07:17,776] Trial 30 pruned.
# [I 2025-11-26 01:08:17,562] Trial 31 finished with value: 0.9977923405417428 and parameters: {'n_layers': 2, 'units_l0': 192, 'units_l1': 64, 'activation': 'tanh', 'alpha': 4.393452294864059e-05, 'learning_rate': 'constant', 'learning_rate_init': 0.0003984691492155922, 'batch_size': 64}. Best is trial 31 with value: 0.9977923405417428.
# [I 2025-11-26 01:09:18,369] Trial 32 finished with value: 0.9976618137004231 and parameters: {'n_layers': 2, 'units_l0': 192, 'units_l1': 64, 'activation': 'tanh', 'alpha': 1.5690994911039127e-05, 'learning_rate': 'constant', 'learning_rate_init': 0.00026094345178676737, 'batch_size': 64}. Best is trial 31 with value: 0.9977923405417428.
# [I 2025-11-26 01:10:19,154] Trial 33 finished with value: 0.997667283259145 and parameters: {'n_layers': 2, 'units_l0': 192, 'units_l1': 64, 'activation': 'tanh', 'alpha': 1.4805774459296818e-05, 'learning_rate': 'constant', 'learning_rate_init': 0.0002674007747647176, 'batch_size': 64}. Best is trial 31 with value: 0.9977923405417428.
# [I 2025-11-26 01:11:27,324] Trial 34 finished with value: 0.9972857941953804 and parameters: {'n_layers': 2, 'units_l0': 192, 'units_l1': 64, 'activation': 'tanh', 'alpha': 7.933095456501527e-06, 'learning_rate': 'constant', 'learning_rate_init': 0.00012519589660037075, 'batch_size': 64}. Best is trial 31 with value: 0.9977923405417428.
# [I 2025-11-26 01:12:13,077] Trial 35 pruned.
# [I 2025-11-26 01:12:44,651] Trial 36 pruned.
# [I 2025-11-26 01:14:00,935] Trial 37 finished with value: 0.997709863375929 and parameters: {'n_layers': 2, 'units_l0': 192, 'units_l1': 64, 'activation': 'tanh', 'alpha': 3.3096539839432147e-06, 'learning_rate': 'constant', 'learning_rate_init': 0.00036726946908162644, 'batch_size': 64}. Best is trial 31 with value: 0.9977923405417428.
# [I 2025-11-26 01:15:04,909] Trial 38 pruned.
# [I 2025-11-26 01:15:59,562] Trial 39 pruned.
# Best R2: 0.9977923405417428
# Best Params: {'n_layers': 2, 'units_l0': 192, 'units_l1': 64, 'activation': 'tanh', 'alpha': 4.393452294864059e-05, 'learning_rate': 'constant', 'learning_rate_init': 0.0003984691492155922, 'batch_size': 64}

# %%
best = study.best_params

# Rebuild hidden_layer_sizes
n_layers = best["n_layers"]
hidden_layer_sizes = tuple([
    best[f"units_l{i}"] for i in range(n_layers)
])

# Remove Optuna-only keys
best_norm_ms = best.copy()
best_norm_ms.pop("n_layers")
for i in range(n_layers):
    best_norm_ms.pop(f"units_l{i}")

# Inject the real MLP param
best_norm_ms["hidden_layer_sizes"] = hidden_layer_sizes

# Now build the model
mlp_norm_ms = MLPRegressor(**best_norm_ms)
mlp_norm_ms.fit(x_train_norm_ms, y_train)
# Out:
# MLPRegressor(activation='tanh', alpha=4.393452294864059e-05, batch_size=64,
#              hidden_layer_sizes=(192, 64),
#              learning_rate_init=0.0003984691492155922)

# %%
from sklearn.neural_network import MLPRegressor
best_norm_ms = {'activation': 'tanh', 'alpha': 4.393452294864059e-05, 'learning_rate': 'constant', 'learning_rate_init': 0.0003984691492155922, 'batch_size': 64, 'hidden_layer_sizes': (192, 64)}
mlp_norm_ms = MLPRegressor(**best_norm_ms)
mlp_norm_ms.fit(x_train_norm_ms, y_train)
# Out:
# MLPRegressor(activation='tanh', alpha=4.393452294864059e-05, batch_size=64,
#              hidden_layer_sizes=(192, 64),
#              learning_rate_init=0.0003984691492155922)

# %%
import joblib

# suppose your trained model is 'model'
mlp_norm_ms=joblib.load( "mlp_norm_ms.pkl")

# %%
y_test_pred_norm_ms =  mlp_norm_ms.predict(x_test_norm_ms)

# %%
from sklearn.metrics import r2_score

results = {
    "mlp_norm_ms": [r2_score(y_train, mlp_norm_ms.predict(x_train_norm_ms)), r2_score(y_test, mlp_norm_ms.predict(x_test_norm_ms))]
}

# %%
result_df = pd.DataFrame(results, index=["train", "test"])
result_df
# Out:
#        mlp_norm_ms
# train     0.992976
# test      0.991807

# %%
from sklearn.metrics import mean_absolute_error

results_mae = {
    "mlp_norm_ms": [mean_absolute_error(y_train, mlp_norm_ms.predict(x_train_norm_ms)), mean_absolute_error(y_test, mlp_norm_ms.predict(x_test_norm_ms))]
}

result_mae_df = pd.DataFrame(results_mae, index=["train", "test"])
result_mae_df
# Out:
#        mlp_norm_ms
# train     0.034840
# test      0.035468

# %%
from sklearn.metrics import mean_squared_error

results_mse = {
    "mlp_norm_ms": [mean_squared_error(y_train, mlp_norm_ms.predict(x_train_norm_ms)), mean_squared_error(y_test, mlp_norm_ms.predict(x_test_norm_ms))]
}

result_mse_df = pd.DataFrame(results_mse, index=["train", "test"])
result_mse_df
# Out:
#        mlp_norm_ms
# train     0.002166
# test      0.002481

# %%
result_rmse_df = np.sqrt(result_mse_df)
result_rmse_df
# Out:
#        mlp_norm_ms
# train     0.046544
# test      0.049814

# %%
y_norm_ms = np.expm1(mlp_norm_ms.predict(x_jwst_norm_ms))

# %%
print("MLP NORM MS: ", y_norm_ms.mean(axis = 0))
# Out:
# MLP NORM MS:  -0.9992902853444177

# %%
print("mlp norm ms params : ",best_norm_ms)
# Out:
# mlp norm ms params :  {'activation': 'tanh', 'alpha': 4.393452294864059e-05, 'learning_rate': 'constant', 'learning_rate_init': 0.0003984691492155922, 'batch_size': 64, 'hidden_layer_sizes': (192, 64)}

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.scatter(y_test, y_test_pred_norm_ms, s=5)

m = min(y_test.min(), y_test_pred_norm_ms.min())
M = max(y_test.max(), y_test_pred_norm_ms.max())

plt.plot([m, M], [m, M], 'r--')
    
plt.xlabel("True")
plt.ylabel("Predicted")
plt.title("Temperature - MLP(NMS)")
plt.show()

# %%
true = y_test       # 1D array
pred = y_test_pred_norm_ms  # 1D array

errors = np.abs(true - pred)

# Number of quantile bins (same as paper: ~20 bins)
num_bins = 20

# Bin according to TRUE values
df = pd.DataFrame({"true": true, "err": errors})
df["bin"] = pd.qcut(df["true"], q=num_bins, duplicates="drop")

# Compute stats inside each bin
bin_centers = df.groupby("bin")["true"].mean()
median_err   = df.groupby("bin")["err"].median()
low_err      = df.groupby("bin")["err"].quantile(0.25)   # lower quartile
high_err     = df.groupby("bin")["err"].quantile(0.75)   # upper quartile

plt.figure(figsize=(6,4))

# Shaded region = IQR (or use std if you prefer)
plt.fill_between(
    bin_centers,
    low_err,
    high_err,
    alpha=0.25
)

# Median error curve
plt.plot(bin_centers, median_err, label="median abs error")

plt.xlabel("True Value (binned)")
plt.ylabel("Absolute Error")
plt.title("Quantile-Binned Error Curve Temperature - MLP(NMS)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\Hamshith\AppData\Local\Temp\ipykernel_13944\1700227537.py:14: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   bin_centers = df.groupby("bin")["true"].mean()
# C:\Users\Hamshith\AppData\Local\Temp\ipykernel_13944\1700227537.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   median_err   = df.groupby("bin")["err"].median()
# C:\Users\Hamshith\AppData\Local\Temp\ipykernel_13944\1700227537.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   low_err      = df.groupby("bin")["err"].quantile(0.25)   # lower quartile
# C:\Users\Hamshith\AppData\Local\Temp\ipykernel_13944\1700227537.py:17: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   high_err     = df.groupby("bin")["err"].quantile(0.75)   # upper quartile

# %%
import joblib

# suppose your trained model is 'model'
joblib.dump(mlp_norm_ms, "mlp_norm_ms.pkl")
# Out:
# ['mlp_norm_ms.pkl']
