# %%
import numpy as np
import pandas as pd

# %%
abc_df = pd.read_csv('ABC_Feature_Matrix_Random.csv')
jwst_df = pd.read_csv('Interpolated_WASP-39b.csv')

# %%
x_spec = abc_df.iloc[:, 1:53]
y = abc_df.iloc[:, 53]

# %%
x_jwst = jwst_df.iloc[:,1:]

# %%
#Train Test Split
from sklearn.model_selection import train_test_split
x_spec_train, x_spec_test, y_train, y_test = train_test_split(x_spec, y, test_size = 0.2, random_state = 42)

# %%
X_train = x_spec_train.to_numpy()
X_test = x_spec_test.to_numpy()
X_jwst = x_jwst.to_numpy()

# %%
#Using Standard Scaler

from sklearn.preprocessing import StandardScaler
scaler_standard = StandardScaler()

x_train_std = scaler_standard.fit_transform(X_train)
x_test_std = scaler_standard.fit_transform(X_test)
x_jwst_std = scaler_standard.fit_transform(X_jwst)

# %%
y_train = np.log1p(y_train)
y_test   = np.log1p(y_test)

# %%
import optuna
import numpy as np
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.neural_network import MLPRegressor

# Validation split
X_tr, X_val, y_tr, y_val = train_test_split(
    x_train_std, y_train, test_size=0.20, random_state=42
)

def objective(trial):

    # Depth: restrict to 1–2 layers (3+ is too slow)
    n_layers = trial.suggest_int("n_layers", 1, 2)

    # Width: 64–192 units per layer (good speed/accuracy balance)
    hidden_layer_sizes = tuple([
        trial.suggest_int(f"units_l{i}", 64, 192, step=64)
        for i in range(n_layers)
    ])

    params = {
        "hidden_layer_sizes": hidden_layer_sizes,

        "activation": "relu",

        "alpha": trial.suggest_float("alpha", 1e-6, 1e-2, log=True),

        "beta_1": trial.suggest_float("beta_1", 0.85, 0.93),
        "beta_2": trial.suggest_float("beta_2", 0.90, 0.98),

        "shuffle": trial.suggest_categorical("shuffle", [True, False]),
        "n_iter_no_change": trial.suggest_int("n_iter_no_change", 5, 10),

        "solver": "adam",
        "learning_rate": "adaptive",
        "learning_rate_init": trial.suggest_float("learning_rate_init", 5e-4, 5e-3, log=True),

        "batch_size": trial.suggest_categorical("batch_size", [128, 256]),

        "max_iter": 250,
        "early_stopping": True,
        "validation_fraction": 0.15,
        "random_state": 42,
    }

    model = MLPRegressor(**params)
    model.fit(X_tr, y_tr)

    preds = model.predict(X_val)
    r2 = r2_score(y_val, preds)

    trial.report(r2, step=0)
    if trial.should_prune():
        raise optuna.exceptions.TrialPruned()

    return r2


study = optuna.create_study(
    direction="maximize",
    sampler=optuna.samplers.TPESampler(),
    pruner=optuna.pruners.MedianPruner()
)

study.optimize(objective, n_trials=40, show_progress_bar=True)

print("Best R2:", study.best_value)
print("Best Params:", study.best_params)
# Out:
# [I 2025-11-26 13:47:53,897] A new study created in memory with name: no-name-1ffd8106-10a6-4022-82f3-0e0a2c9898fd
#   0%|          | 0/40 [00:00<?, ?it/s]
# [I 2025-11-26 13:47:55,199] Trial 0 finished with value: -0.09100174581784737 and parameters: {'n_layers': 1, 'units_l0': 64, 'alpha': 0.0050861021529294, 'beta_1': 0.8586868768707203, 'beta_2': 0.9039259191721103, 'shuffle': True, 'n_iter_no_change': 6, 'learning_rate_init': 0.002192285581377195, 'batch_size': 256}. Best is trial 0 with value: -0.09100174581784737.
# [I 2025-11-26 13:48:06,482] Trial 1 finished with value: -0.04671007138121963 and parameters: {'n_layers': 1, 'units_l0': 128, 'alpha': 4.014003421914563e-05, 'beta_1': 0.9021870919341318, 'beta_2': 0.9328821835675929, 'shuffle': False, 'n_iter_no_change': 6, 'learning_rate_init': 0.0011245705510648325, 'batch_size': 256}. Best is trial 1 with value: -0.04671007138121963.
# [I 2025-11-26 13:48:26,504] Trial 2 finished with value: -3.580366031695452 and parameters: {'n_layers': 1, 'units_l0': 128, 'alpha': 4.15060957845355e-05, 'beta_1': 0.8525470939288701, 'beta_2': 0.9388889371662726, 'shuffle': False, 'n_iter_no_change': 5, 'learning_rate_init': 0.00446384329689538, 'batch_size': 128}. Best is trial 1 with value: -0.04671007138121963.
# [I 2025-11-26 13:48:38,386] Trial 3 finished with value: 0.10036021354284164 and parameters: {'n_layers': 2, 'units_l0': 64, 'units_l1': 128, 'alpha': 0.0004674233894771131, 'beta_1': 0.9186762901008878, 'beta_2': 0.9418657313581577, 'shuffle': True, 'n_iter_no_change': 8, 'learning_rate_init': 0.0013778637160475117, 'batch_size': 128}. Best is trial 3 with value: 0.10036021354284164.
# [I 2025-11-26 13:48:48,436] Trial 4 finished with value: -0.6897962875818013 and parameters: {'n_layers': 1, 'units_l0': 192, 'alpha': 0.00032997756227873607, 'beta_1': 0.8979172012901948, 'beta_2': 0.9067835361560062, 'shuffle': False, 'n_iter_no_change': 9, 'learning_rate_init': 0.0005179945055003228, 'batch_size': 128}. Best is trial 3 with value: 0.10036021354284164.
# [I 2025-11-26 13:48:59,614] Trial 5 pruned.
# [I 2025-11-26 13:49:25,486] Trial 6 pruned.
# [I 2025-11-26 13:49:31,402] Trial 7 pruned.
# [I 2025-11-26 13:49:54,427] Trial 8 finished with value: 0.13747692430983338 and parameters: {'n_layers': 1, 'units_l0': 128, 'alpha': 0.0003206852962689354, 'beta_1': 0.9084418213198845, 'beta_2': 0.9293134707427925, 'shuffle': True, 'n_iter_no_change': 7, 'learning_rate_init': 0.0005046629754955023, 'batch_size': 128}. Best is trial 8 with value: 0.13747692430983338.
# [I 2025-11-26 13:50:01,185] Trial 9 finished with value: 0.08705721241911535 and parameters: {'n_layers': 2, 'units_l0': 128, 'units_l1': 64, 'alpha': 1.8909281869662407e-06, 'beta_1': 0.9249418322506079, 'beta_2': 0.9764733463208672, 'shuffle': False, 'n_iter_no_change': 5, 'learning_rate_init': 0.0033077188047087166, 'batch_size': 256}. Best is trial 8 with value: 0.13747692430983338.
# [I 2025-11-26 13:50:03,582] Trial 10 pruned.
# [I 2025-11-26 13:50:47,182] Trial 11 finished with value: 0.27677470776296553 and parameters: {'n_layers': 2, 'units_l0': 64, 'units_l1': 192, 'alpha': 0.000915868468322543, 'beta_1': 0.9265568630058063, 'beta_2': 0.9523929895164243, 'shuffle': True, 'n_iter_no_change': 7, 'learning_rate_init': 0.0015156110493117316, 'batch_size': 128}. Best is trial 11 with value: 0.27677470776296553.
# [I 2025-11-26 13:52:32,109] Trial 12 finished with value: 0.19005345271258145 and parameters: {'n_layers': 2, 'units_l0': 64, 'units_l1': 192, 'alpha': 0.0012422730373147534, 'beta_1': 0.9273434188003268, 'beta_2': 0.9598078354744345, 'shuffle': True, 'n_iter_no_change': 7, 'learning_rate_init': 0.001803675979051061, 'batch_size': 128}. Best is trial 11 with value: 0.27677470776296553.
# [I 2025-11-26 13:52:42,542] Trial 13 finished with value: 0.13012881934784692 and parameters: {'n_layers': 2, 'units_l0': 64, 'units_l1': 192, 'alpha': 0.0012775115183336588, 'beta_1': 0.9234656716629371, 'beta_2': 0.9565046076348176, 'shuffle': True, 'n_iter_no_change': 6, 'learning_rate_init': 0.0018106589413364822, 'batch_size': 128}. Best is trial 11 with value: 0.27677470776296553.
# [I 2025-11-26 13:53:50,223] Trial 14 finished with value: 0.33218598422659074 and parameters: {'n_layers': 2, 'units_l0': 64, 'units_l1': 192, 'alpha': 0.0015467962884723454, 'beta_1': 0.9298103726798786, 'beta_2': 0.9547171529809739, 'shuffle': True, 'n_iter_no_change': 7, 'learning_rate_init': 0.0015857322813702139, 'batch_size': 128}. Best is trial 14 with value: 0.33218598422659074.
# [I 2025-11-26 13:53:57,577] Trial 15 pruned.
# [I 2025-11-26 13:54:01,759] Trial 16 pruned.
# [I 2025-11-26 13:55:06,092] Trial 17 finished with value: 0.38948298567367157 and parameters: {'n_layers': 2, 'units_l0': 64, 'units_l1': 192, 'alpha': 5.8359631130677296e-05, 'beta_1': 0.9124230371969992, 'beta_2': 0.9506872157593276, 'shuffle': True, 'n_iter_no_change': 7, 'learning_rate_init': 0.002561631918582989, 'batch_size': 128}. Best is trial 17 with value: 0.38948298567367157.
# [I 2025-11-26 13:56:36,173] Trial 18 finished with value: 0.42278899837744954 and parameters: {'n_layers': 2, 'units_l0': 64, 'units_l1': 192, 'alpha': 2.625175195274628e-05, 'beta_1': 0.9112445285821308, 'beta_2': 0.9659614045210757, 'shuffle': True, 'n_iter_no_change': 9, 'learning_rate_init': 0.0030247574068035053, 'batch_size': 128}. Best is trial 18 with value: 0.42278899837744954.
# [I 2025-11-26 13:56:58,745] Trial 19 pruned.
# [I 2025-11-26 13:57:06,408] Trial 20 pruned.
# [I 2025-11-26 13:57:51,616] Trial 21 finished with value: 0.3844287650333683 and parameters: {'n_layers': 2, 'units_l0': 64, 'units_l1': 192, 'alpha': 9.289172126616711e-05, 'beta_1': 0.9167548270291255, 'beta_2': 0.9493746267376004, 'shuffle': True, 'n_iter_no_change': 8, 'learning_rate_init': 0.002637869716197667, 'batch_size': 128}. Best is trial 18 with value: 0.42278899837744954.
# [I 2025-11-26 13:58:39,485] Trial 22 finished with value: 0.2650676659125699 and parameters: {'n_layers': 2, 'units_l0': 64, 'units_l1': 192, 'alpha': 9.981541227352355e-05, 'beta_1': 0.9026950799065637, 'beta_2': 0.946547173625866, 'shuffle': True, 'n_iter_no_change': 9, 'learning_rate_init': 0.0026808618126179253, 'batch_size': 128}. Best is trial 18 with value: 0.42278899837744954.
# [I 2025-11-26 13:59:15,405] Trial 23 finished with value: 0.40498052876312707 and parameters: {'n_layers': 2, 'units_l0': 64, 'units_l1': 192, 'alpha': 1.516729862402759e-05, 'beta_1': 0.916599003432093, 'beta_2': 0.9638670937644844, 'shuffle': True, 'n_iter_no_change': 8, 'learning_rate_init': 0.003637605467909651, 'batch_size': 128}. Best is trial 18 with value: 0.42278899837744954.
# [I 2025-11-26 13:59:19,820] Trial 24 pruned.
# [I 2025-11-26 14:00:38,472] Trial 25 finished with value: 0.3985263778425482 and parameters: {'n_layers': 2, 'units_l0': 64, 'units_l1': 192, 'alpha': 7.0980948703558115e-06, 'beta_1': 0.9039804024451394, 'beta_2': 0.9713877112363094, 'shuffle': True, 'n_iter_no_change': 10, 'learning_rate_init': 0.0022249512079093752, 'batch_size': 128}. Best is trial 18 with value: 0.42278899837744954.
# [I 2025-11-26 14:00:58,384] Trial 26 finished with value: 0.22447229527859325 and parameters: {'n_layers': 2, 'units_l0': 64, 'units_l1': 192, 'alpha': 6.061930659625116e-06, 'beta_1': 0.9035818040391528, 'beta_2': 0.9731093686447284, 'shuffle': False, 'n_iter_no_change': 10, 'learning_rate_init': 0.00380544408370841, 'batch_size': 256}. Best is trial 18 with value: 0.42278899837744954.
# [I 2025-11-26 14:01:10,278] Trial 27 pruned.
# [I 2025-11-26 14:01:15,463] Trial 28 pruned.
# [I 2025-11-26 14:02:49,079] Trial 29 finished with value: 0.42994377095771985 and parameters: {'n_layers': 2, 'units_l0': 64, 'units_l1': 192, 'alpha': 1.0706211560614642e-05, 'beta_1': 0.8761722533059852, 'beta_2': 0.9729945763193358, 'shuffle': True, 'n_iter_no_change': 9, 'learning_rate_init': 0.0021724398102450984, 'batch_size': 256}. Best is trial 29 with value: 0.42994377095771985.
# [I 2025-11-26 14:03:33,289] Trial 30 finished with value: 0.2957970316674271 and parameters: {'n_layers': 2, 'units_l0': 64, 'units_l1': 192, 'alpha': 1.4094396398794142e-05, 'beta_1': 0.8676202737808426, 'beta_2': 0.9587725376494587, 'shuffle': True, 'n_iter_no_change': 9, 'learning_rate_init': 0.003907744973988615, 'batch_size': 256}. Best is trial 29 with value: 0.42994377095771985.
# [I 2025-11-26 14:04:35,997] Trial 31 finished with value: 0.3562009665831156 and parameters: {'n_layers': 2, 'units_l0': 64, 'units_l1': 192, 'alpha': 9.153733623948652e-06, 'beta_1': 0.8712811668330926, 'beta_2': 0.9731104476909717, 'shuffle': True, 'n_iter_no_change': 10, 'learning_rate_init': 0.002265616468427837, 'batch_size': 256}. Best is trial 29 with value: 0.42994377095771985.
# [I 2025-11-26 14:05:49,059] Trial 32 finished with value: 0.4048062525024143 and parameters: {'n_layers': 2, 'units_l0': 64, 'units_l1': 192, 'alpha': 2.7249952853804435e-06, 'beta_1': 0.8797149427722766, 'beta_2': 0.9724638986451393, 'shuffle': True, 'n_iter_no_change': 9, 'learning_rate_init': 0.002141851254624827, 'batch_size': 256}. Best is trial 29 with value: 0.42994377095771985.
# [I 2025-11-26 14:06:50,597] Trial 33 finished with value: 0.384469955719723 and parameters: {'n_layers': 2, 'units_l0': 64, 'units_l1': 192, 'alpha': 2.907861265016838e-06, 'beta_1': 0.8768850939700242, 'beta_2': 0.9645305507648881, 'shuffle': True, 'n_iter_no_change': 9, 'learning_rate_init': 0.0029429278517484852, 'batch_size': 256}. Best is trial 29 with value: 0.42994377095771985.
# [I 2025-11-26 14:07:01,322] Trial 34 pruned.
# [I 2025-11-26 14:07:04,129] Trial 35 pruned.
# [I 2025-11-26 14:07:25,261] Trial 36 pruned.
# [I 2025-11-26 14:07:30,976] Trial 37 pruned.
# [I 2025-11-26 14:08:04,644] Trial 38 pruned.
# [I 2025-11-26 14:08:11,232] Trial 39 pruned.
# Best R2: 0.42994377095771985
# Best Params: {'n_layers': 2, 'units_l0': 64, 'units_l1': 192, 'alpha': 1.0706211560614642e-05, 'beta_1': 0.8761722533059852, 'beta_2': 0.9729945763193358, 'shuffle': True, 'n_iter_no_change': 9, 'learning_rate_init': 0.0021724398102450984, 'batch_size': 256}

# %%
best = study.best_params

# Rebuild hidden_layer_sizes
n_layers = best["n_layers"]
hidden_layer_sizes = tuple([
    best[f"units_l{i}"] for i in range(n_layers)
])

# Remove Optuna-only keys
best_std = best.copy()
best_std.pop("n_layers")
for i in range(n_layers):
    best_std.pop(f"units_l{i}")

# Inject the real MLP param
best_std["hidden_layer_sizes"] = hidden_layer_sizes

mlp_std = MLPRegressor(**best_std)
mlp_std.fit(x_train_std, y_train)
# Out:
# MLPRegressor(alpha=1.0706211560614642e-05, batch_size=256,
#              beta_1=0.8761722533059852, beta_2=0.9729945763193358,
#              hidden_layer_sizes=(64, 192),
#              learning_rate_init=0.0021724398102450984, n_iter_no_change=9)

# %%
import joblib

# suppose your trained model is 'model'
mlp_std=joblib.load( "mlp_std.pkl")

# %%
y_test_pred_std =  mlp_std.predict(x_test_std)

# %%
from sklearn.metrics import r2_score

results = {
    "mlp_std": [r2_score(y_train, mlp_std.predict(x_train_std)), r2_score(y_test, mlp_std.predict(x_test_std))]
}

# %%
result_df = pd.DataFrame(results, index=["train", "test"])
result_df
# Out:
#           mlp_std
# train    0.358795
# test  -535.599695

# %%
from sklearn.metrics import mean_absolute_error

results_mae = {
    "mlp_std": [mean_absolute_error(y_train, mlp_std.predict(x_train_std)), mean_absolute_error(y_test, mlp_std.predict(x_test_std))]
}

result_mae_df = pd.DataFrame(results_mae, index=["train", "test"])
result_mae_df
# Out:
#          mlp_std
# train   0.322108
# test   11.244097

# %%
from sklearn.metrics import mean_squared_error

results_mse = {
    "mlp_std": [mean_squared_error(y_train, mlp_std.predict(x_train_std)), mean_squared_error(y_test, mlp_std.predict(x_test_std))]
}

result_mse_df = pd.DataFrame(results_mse, index=["train", "test"])
result_mse_df
# Out:
#           mlp_std
# train    0.197775
# test   162.519755

# %%
result_rmse_df = np.sqrt(result_mse_df)
result_rmse_df
# Out:
#          mlp_std
# train   0.444719
# test   12.748324

# %%
y_std = np.expm1(mlp_std.predict(x_jwst_std))

# %%
print("MLP STD: ", y_std.mean(axis = 0))
# Out:
# MLP STD:  1.96596660167824e+51

# %%
print("mlp std params : ",mlp_std.get_params())
# Out:
# mlp std params :  {'activation': 'relu', 'alpha': 1.0706211560614642e-05, 'batch_size': 256, 'beta_1': 0.8761722533059852, 'beta_2': 0.9729945763193358, 'early_stopping': False, 'epsilon': 1e-08, 'hidden_layer_sizes': (64, 192), 'learning_rate': 'constant', 'learning_rate_init': 0.0021724398102450984, 'loss': 'squared_error', 'max_fun': 15000, 'max_iter': 200, 'momentum': 0.9, 'n_iter_no_change': 9, 'nesterovs_momentum': True, 'power_t': 0.5, 'random_state': None, 'shuffle': True, 'solver': 'adam', 'tol': 0.0001, 'validation_fraction': 0.1, 'verbose': False, 'warm_start': False}

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.scatter(y_test, y_test_pred_std, s=5)

m = min(y_test.min(), y_test_pred_std.min())
M = max(y_test.max(), y_test_pred_std.max())

plt.plot([m, M], [m, M], 'r--')
    
plt.xlabel("True")
plt.ylabel("Predicted")
plt.title("Temperature- MLP(S)")
plt.show()

# %%
true = y_test       # 1D array
pred = y_test_pred_std  # 1D array

errors = np.abs(true - pred)

# Number of quantile bins (same as paper: ~20 bins)
num_bins = 20

# Bin according to TRUE values
df = pd.DataFrame({"true": true, "err": errors})
df["bin"] = pd.qcut(df["true"], q=num_bins, duplicates="drop")

# Compute stats inside each bin
bin_centers = df.groupby("bin")["true"].mean()
median_err   = df.groupby("bin")["err"].median()
low_err      = df.groupby("bin")["err"].quantile(0.25)   # lower quartile
high_err     = df.groupby("bin")["err"].quantile(0.75)   # upper quartile

plt.figure(figsize=(6,4))

# Shaded region = IQR (or use std if you prefer)
plt.fill_between(
    bin_centers,
    low_err,
    high_err,
    alpha=0.25
)

# Median error curve
plt.plot(bin_centers, median_err, label="median abs error")

plt.xlabel("True Value (binned)")
plt.ylabel("Absolute Error")
plt.title("Quantile-Binned Error Curve Temperature - MLP(S)")
plt.legend()
plt.grid(True)
plt.show()
# Out:
# C:\Users\Hamshith\AppData\Local\Temp\ipykernel_18644\2580531820.py:14: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   bin_centers = df.groupby("bin")["true"].mean()
# C:\Users\Hamshith\AppData\Local\Temp\ipykernel_18644\2580531820.py:15: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   median_err   = df.groupby("bin")["err"].median()
# C:\Users\Hamshith\AppData\Local\Temp\ipykernel_18644\2580531820.py:16: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   low_err      = df.groupby("bin")["err"].quantile(0.25)   # lower quartile
# C:\Users\Hamshith\AppData\Local\Temp\ipykernel_18644\2580531820.py:17: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   high_err     = df.groupby("bin")["err"].quantile(0.75)   # upper quartile

# %%
import joblib

# suppose your trained model is 'model'
joblib.dump(mlp_std, "mlp_std.pkl")
# Out:
# ['mlp_std.pkl']
